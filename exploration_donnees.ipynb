# %%
from .. import config
import pandas
import numpy
import matplotlib
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-2b76e351628c> in <module>
# ----> 1 from .. import config
#       2 import pandas
#       3 import numpy
#       4 import matplotlib
#
# ImportError: attempted relative import with no known parent package

# %% [markdown]
# # data import

# %% [markdown]
# # data exploration
